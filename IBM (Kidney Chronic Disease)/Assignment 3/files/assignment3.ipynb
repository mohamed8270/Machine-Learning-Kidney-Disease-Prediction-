# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/Mohamed/Desktop/IBM CKD/Assignment 3/data/abalone.csv')

# %%
data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
data.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Univariate
plt.scatter(data.index,data['Length'])
plt.show()

# %%
import numpy as np
pd.pivot_table(data,index =["Length","Diameter"],columns=["Height"],aggfunc=[np.sum])
# Out:
# C:\Users\Mohamed\AppData\Local\Temp\ipykernel_11684\2552538727.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.pivot_table(data,index =["Length","Diameter"],columns=["Height"],aggfunc=[np.sum])
#                   sum                                                        \
#                 Rings
# Height          0.000 0.010 0.015 0.020 0.025 0.030 0.035 0.040 0.045 0.050
# Length Diameter
# 0.075  0.055      NaN   1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 0.110  0.090      NaN   NaN   NaN   NaN   NaN   3.0   NaN   NaN   NaN   NaN
# 0.130  0.095      NaN   NaN   NaN   NaN   NaN   NaN   4.0   NaN   NaN   NaN
#        0.100      NaN   NaN   NaN   NaN   NaN   3.0   NaN   NaN   NaN   NaN
# 0.135  0.130      NaN   NaN   NaN   NaN   NaN   NaN   NaN   4.0   NaN   NaN
# ...

# %%
# Bivariate
from sympy import plot

sns.barplot(x='Length',y='Height',data=data)
sns.countplot(x='Length',data=data)
# Out:
# <AxesSubplot: xlabel='Length', ylabel='count'>

# %%
data[data['Length'] < 100].sample(100).plot.scatter(x='Length', y='Diameter')
# Out:
# <AxesSubplot: xlabel='Length', ylabel='Diameter'>

# %%
data.plot.line()
# Out:
# <AxesSubplot: >

# %%
# Multivariate
sns.pairplot(data=data,height=2)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In [16], line 2
#       1 # Multivariate
# ----> 2 sns.pairplot(data=data,height=2)
#
# File c:\Users\Mohamed\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:2144, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2142 diag_kws.setdefault("legend", False)
#    2143 if diag_kind == "hist":
# -> 2144     grid.map_diag(histplot, **diag_kws)
#    2145 elif diag_kind == "kde":
#    2146     diag_kws.setdefault("fill", True)
#
# File c:\Users\Mohamed\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:1507, in PairGrid.map_diag(self, func, **kwargs)
#    1505     plot_kwargs.setdefault("hue_order", self._hue_order)
# ...

# %%
# Statististcal
lengthaverage = data['Length'].mean()
print(lengthaverage)

diameteraverage = data['Diameter'].mean()
print(diameteraverage)

heightaverage = data['Height'].mean()
print(heightaverage)
# Out:
# 0.5239920995930094
# 0.40788125448886764
# 0.13951639932966242

# %%
bool_series = pd.isnull(data["Diameter"])
data[bool_series]
# Out:
# Empty DataFrame
# Columns: [Sex, Length, Diameter, Height, Whole weight, Shucked weight, Viscera weight, Shell weight, Rings]
# Index: []

# %%
bool_series = pd.notnull(data["Diameter"])
data[bool_series]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df = pd.DataFrame(data)
df.fillna(0)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
#length have high outlier, calculated by statistical method
lengthaverage = data['Length'].mean()
print(lengthaverage)
fig = plt.hist('lengthaverage')
# Out:
# 0.5239920995930094

# %%
data_numeric= data[['Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight','Rings']]
data_alphabet=[['Sex']]
print(data['Length'].unique())
print(data['Diameter'].unique())
print(data['Height'].unique())
print(data['Whole weight'].unique())
print(data['Shucked weight'].unique())
print(data['Viscera weight'].unique())
print(data['Shell weight'].unique())
print(data['Rings'].unique())
# Out:
# [0.455 0.35  0.53  0.44  0.33  0.425 0.545 0.475 0.55  0.525 0.43  0.49
#  0.535 0.47  0.5   0.355 0.365 0.45  0.38  0.565 0.615 0.56  0.58  0.59
#  0.605 0.575 0.68  0.665 0.705 0.465 0.54  0.24  0.205 0.21  0.39  0.46
#  0.325 0.52  0.4   0.485 0.405 0.445 0.245 0.505 0.595 0.31  0.555 0.57
#  0.6   0.62  0.625 0.695 0.36  0.51  0.435 0.495 0.385 0.515 0.37  0.27
#  0.375 0.7   0.71  0.265 0.305 0.345 0.65  0.28  0.175 0.17  0.635 0.645
#  0.61  0.725 0.235 0.315 0.225 0.64  0.63  0.585 0.42  0.335 0.415 0.275
#  0.295 0.075 0.13  0.11  0.16  0.23  0.3   0.32  0.655 0.66  0.2   0.165
#  0.19  0.74  0.34  0.675 0.745 0.685 0.69  0.67  0.29  0.26  0.395 0.41
#  0.22  0.255 0.735 0.155 0.48  0.195 0.25  0.18  0.15  0.215 0.73  0.715
#  0.765 0.185 0.285 0.72  0.75  0.755 0.78  0.815 0.14  0.77  0.775 0.76
#  0.135 0.8  ]
# [0.365 0.265 0.42  0.255 0.3   0.415 0.425 0.37  0.44  0.38  0.35  0.405
#  0.355 0.4   0.28  0.34  0.295 0.32  0.275 0.48  0.45  0.445 0.475 0.47
# ...

# %%
# Encoding
from sklearn.preprocessing import LabelEncoder
s_encoder = LabelEncoder()
s_encoder.fit(data_numeric['Length'])
LabelEncoder()
s_values = s_encoder.transform(data_numeric['Length'])
print("Before Encoding:", list(data_numeric['Length'][-10:]))
print("After Encoding:", s_values[-10:])
print("The inverse from the encoding result:", s_encoder.inverse_transform(s_values[-10:]))
# Out:
# Before Encoding: [0.5, 0.515, 0.52, 0.55, 0.56, 0.565, 0.59, 0.6, 0.625, 0.71]
# After Encoding: [ 75  78  79  85  87  88  93  95 100 117]
# The inverse from the encoding result: [0.5   0.515 0.52  0.55  0.56  0.565 0.59  0.6   0.625 0.71 ]

# %%
# Dependent values
X = df.iloc[:, :-1].values
print(X)
# Out:
# [['M' 0.455 0.365 ... 0.2245 0.101 0.15]
#  ['M' 0.35 0.265 ... 0.0995 0.0485 0.07]
#  ['F' 0.53 0.42 ... 0.2565 0.1415 0.21]
#  ...
#  ['M' 0.6 0.475 ... 0.5255 0.2875 0.308]
#  ['F' 0.625 0.485 ... 0.531 0.261 0.296]
#  ['M' 0.71 0.555 ... 0.9455 0.3765 0.495]]

# %%
# Independent values
Y = df.iloc[:, -1].values
print(Y)
# Out:
# [15  7  9 ...  9 10 12]

# %%
# Scalling Independent values 
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
import sklearn.metrics as metrics
from sklearn.preprocessing import StandardScaler

data = plt.subplots(figsize=(12, 4))

X_train, X_test, Y_train, Y_test = train_test_split(X, Y)

# Define the pipeline for scaling and model fitting
pipeline = Pipeline([
    ("MinMax Scaling", MinMaxScaler()),
    ("SGD Regression", SGDRegressor())
])

# Scale the data and fit the model
pipeline.fit(X_train, Y_train)

# Evaluate the model
y_pred = pipeline.predict(X_test)
print('Mean Absolute Error: ', mean_absolute_error(y_pred, Y_test))
print('Score', pipeline.score(X_test, Y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [27], line 22
#      16 pipeline = Pipeline([
#      17     ("MinMax Scaling", MinMaxScaler()),
#      18     ("SGD Regression", SGDRegressor())
#      19 ])
#      21 # Scale the data and fit the model
# ---> 22 pipeline.fit(X_train, Y_train)
#      24 # Evaluate the model
#      25 y_pred = pipeline.predict(X_test)
#
# File c:\Users\Mohamed\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py:378, in Pipeline.fit(self, X, y, **fit_params)
#     352 """Fit the model.
#     353
#     354 Fit all the transformers one after the other and transform the
#    (...)
#     375     Pipeline with fitted steps.
#     376 """
#     377 fit_params_steps = self._check_fit_params(**fit_params)
# --> 378 Xt = self._fit(X, y, **fit_params_steps)
# ...

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y)
